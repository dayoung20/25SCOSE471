# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
import pandas as pd

df = pd.read_csv('final_data.csv', encoding='cp949')
# Out:
# /var/folders/9w/_q320mvj3gz1xdsqbkx3_bcr0000gn/T/ipykernel_22471/4045911117.py:5: DtypeWarning: Columns (2,90,93,94,96,98,103,104,105,107,110,111,113) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('final_data.csv', encoding='cp949')

# %%
df
# Out:
#           Idx       ID Class  \
# 0      138803  GEMS204    00
# 1      138802  GEMS202    00
# 2      138801  SEDU408    00
# 3      138800  SEDU330    05
# 4      138799  SEDU330    04
# ...       ...      ...   ...
# 12919  105574  NRSG244     0
# 12920  105573  NRSG240     0
# 12921  105572  NRSG236     0
# 12922  105571  NRSG234     0
# 12923  105570  NRSG172     0
#
#                                                    Title  Year Semester  \
# 0                 조직리더십사례연구화,목(08:00~10:00)/학생군사교육단 205호  2023       2R
# 1               안전및조직관리사례연구화,목(08:00~10:00)/학생군사교육단 305호  2023       2R
# 2      학교현장실습 DL*Course not open for foreign exchange...  2023       2R
# 3      학교폭력예방및학생의이해*Course not open for foreign excha...  2023       2R
# 4      학교폭력예방및학생의이해*Course not open for foreign excha...  2023       2R
# ...                                                  ...   ...      ...
# 12919                              기초간호과학IV월 14:00~15:50  2020       2R
# 12920                               기초간호과학I화 10:00~11:50  2020       2R
# 12921                                  간호진단월 13:00~13:50  2020       2R
# 12922                               간호연구방법론목 10:00~11:50  2020       2R
# 12923                                         건강과국제화(영강)  2020       2R
#
#        Average Score  avg_study  avg_diff  avg_performance  ...   협동  보고서  \
# 0                NaN        NaN       NaN              NaN  ...  0.0  0.0
# 1                NaN        NaN       NaN              NaN  ...  0.0  0.0
# 2                NaN        NaN       NaN              NaN  ...  0.0  0.0
# 3                NaN        NaN       NaN              NaN  ...  0.0  0.0
# 4                3.8        3.2       2.6              2.8  ...  0.0  0.0
# ...              ...        ...       ...              ...  ...  ...  ...
# 12919            3.5        4.9       4.6              4.0  ...  0.0  0.0
# 12920            2.5        4.8       4.1              2.2  ...  0.0  0.0
# 12921            NaN        NaN       NaN              NaN  ...  0.0  0.0
# 12922            2.8        4.5       4.7              2.9  ...  0.0  0.4
# 12923            3.7        3.9       2.4              3.1  ...  0.0  0.0
#
#         실험   태도   기타  출석_거의안함  출석_매번함  출석_아예안함 출석_자주함  출석_종종함
# 0      0.0  0.0  0.0    False   False    False  False   False
# 1      0.0  0.0  0.0    False   False    False  False   False
# 2      0.0  0.0  0.0    False   False    False  False   False
# 3      0.0  0.0  0.0    False   False    False  False   False
# 4      0.0  0.0  0.0    False   False    False   True   False
# ...    ...  ...  ...      ...     ...      ...    ...     ...
# 12919  0.0  0.0  0.0    False   False    False   True   False
# 12920  0.0  0.0  0.0    False    True    False  False   False
# 12921  0.0  0.0  0.0    False   False    False  False   False
# 12922  0.0  0.0  0.0    False   False    False   True   False
# 12923  0.0  0.0  0.0    False    True    False  False   False
#
# [12924 rows x 182 columns]

# %%
# 선택한 컬럼들만 추출
features = ['Average Score', "영강"]
df_selected = df[features].dropna()

# 데이터 정규화
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_selected)

# DBSCAN 클러스터링 수행
dbscan = DBSCAN(eps=0.5, min_samples=5)
clusters = dbscan.fit_predict(scaled_data)

# 클러스터 결과를 데이터프레임에 추가
df_selected['cluster'] = clusters

# 클러스터 분포 확인
df_selected['cluster'].value_counts()
# Out:
# cluster
#  0    8558
#  1       6
# -1       3
# Name: count, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# 데이터 로딩
X, y = load_iris(return_X_y=True)

# 학습/테스트 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# KNN 분류 모델
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

# 예측
predictions = knn.predict(X_test)

# 정확도 확인
accuracy = knn.score(X_test, y_test)
print(f"정확도: {accuracy:.2f}")
# Out:
# 정확도: 1.00

# %%
df = pd.read_csv('final_data.csv', encoding='cp949')
df
# Out:
# /var/folders/9w/_q320mvj3gz1xdsqbkx3_bcr0000gn/T/ipykernel_22471/1185171231.py:1: DtypeWarning: Columns (2,90,93,94,96,98,103,104,105,107,110,111,113) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('final_data.csv', encoding='cp949')
#           Idx       ID Class  \
# 0      138803  GEMS204    00
# 1      138802  GEMS202    00
# 2      138801  SEDU408    00
# 3      138800  SEDU330    05
# 4      138799  SEDU330    04
# ...       ...      ...   ...
# 12919  105574  NRSG244     0
# 12920  105573  NRSG240     0
# 12921  105572  NRSG236     0
# 12922  105571  NRSG234     0
# 12923  105570  NRSG172     0
#
#                                                    Title  Year Semester  \
# 0                 조직리더십사례연구화,목(08:00~10:00)/학생군사교육단 205호  2023       2R
# 1               안전및조직관리사례연구화,목(08:00~10:00)/학생군사교육단 305호  2023       2R
# 2      학교현장실습 DL*Course not open for foreign exchange...  2023       2R
# 3      학교폭력예방및학생의이해*Course not open for foreign excha...  2023       2R
# 4      학교폭력예방및학생의이해*Course not open for foreign excha...  2023       2R
# ...                                                  ...   ...      ...
# 12919                              기초간호과학IV월 14:00~15:50  2020       2R
# 12920                               기초간호과학I화 10:00~11:50  2020       2R
# 12921                                  간호진단월 13:00~13:50  2020       2R
# 12922                               간호연구방법론목 10:00~11:50  2020       2R
# 12923                                         건강과국제화(영강)  2020       2R
#
#        Average Score  avg_study  avg_diff  avg_performance  ...   협동  보고서  \
# 0                NaN        NaN       NaN              NaN  ...  0.0  0.0
# 1                NaN        NaN       NaN              NaN  ...  0.0  0.0
# 2                NaN        NaN       NaN              NaN  ...  0.0  0.0
# 3                NaN        NaN       NaN              NaN  ...  0.0  0.0
# 4                3.8        3.2       2.6              2.8  ...  0.0  0.0
# ...              ...        ...       ...              ...  ...  ...  ...
# 12919            3.5        4.9       4.6              4.0  ...  0.0  0.0
# 12920            2.5        4.8       4.1              2.2  ...  0.0  0.0
# 12921            NaN        NaN       NaN              NaN  ...  0.0  0.0
# 12922            2.8        4.5       4.7              2.9  ...  0.0  0.4
# 12923            3.7        3.9       2.4              3.1  ...  0.0  0.0
#
#         실험   태도   기타  출석_거의안함  출석_매번함  출석_아예안함 출석_자주함  출석_종종함
# 0      0.0  0.0  0.0    False   False    False  False   False
# 1      0.0  0.0  0.0    False   False    False  False   False
# 2      0.0  0.0  0.0    False   False    False  False   False
# 3      0.0  0.0  0.0    False   False    False  False   False
# 4      0.0  0.0  0.0    False   False    False   True   False
# ...    ...  ...  ...      ...     ...      ...    ...     ...
# 12919  0.0  0.0  0.0    False   False    False   True   False
# 12920  0.0  0.0  0.0    False    True    False  False   False
# 12921  0.0  0.0  0.0    False   False    False  False   False
# 12922  0.0  0.0  0.0    False   False    False   True   False
# 12923  0.0  0.0  0.0    False    True    False  False   False
#
# [12924 rows x 182 columns]
